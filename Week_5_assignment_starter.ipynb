# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('churn_data_modified1.csv')
df
# Out:
#       customerID  tenure  PhoneService  Contract  PaymentMethod  \
# 0           5375       1             0         0              2
# 1           3962      34             1         1              3
# 2           2564       2             1         0              3
# 3           5535      45             0         1              0
# 4           6511       2             1         0              2
# ...          ...     ...           ...       ...            ...
# 7038        4853      24             1         1              3
# 7039        1525      72             1         1              1
# 7040        3367      11             0         0              2
# 7041        5934       4             1         0              3
# 7042        2226      66             1         2              0
#
#       MonthlyCharges  TotalCharges  Churn  TotalCharges_final
# 0              29.85         29.85      0               29.85
# 1              56.95       1936.30      0             1936.30
# 2              53.85        107.70      1              107.70
# 3              42.30       1903.50      0             1903.50
# 4              70.70        141.40      1              141.40
# ...              ...           ...    ...                 ...
# 7038           84.80       2035.20      0             2035.20
# 7039          103.20       7430.40      0             7430.40
# 7040           29.60        325.60      0              325.60
# 7041           74.40        297.60      1              297.60
# 7042          105.65       6972.90      0             6972.90
#
# [7043 rows x 9 columns]

# %%
df = df.drop('customerID', axis=1)
df = df.drop('TotalCharges_final', axis=1)

# %%
df
# Out:
#       tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0          1             0         0              2           29.85
# 1         34             1         1              3           56.95
# 2          2             1         0              3           53.85
# 3         45             0         1              0           42.30
# 4          2             1         0              2           70.70
# ...      ...           ...       ...            ...             ...
# 7038      24             1         1              3           84.80
# 7039      72             1         1              1          103.20
# 7040      11             0         0              2           29.60
# 7041       4             1         0              3           74.40
# 7042      66             1         2              0          105.65
#
#       TotalCharges  Churn
# 0            29.85      0
# 1          1936.30      0
# 2           107.70      1
# 3          1903.50      0
# 4           141.40      1
# ...            ...    ...
# 7038       2035.20      0
# 7039       7430.40      0
# 7040        325.60      0
# 7041        297.60      1
# 7042       6972.90      0
#
# [7043 rows x 7 columns]

# %%
# !pip3 install pycaret
from pycaret.classification import *
# Out:
# Requirement already satisfied: pycaret in c:\users\user\downloads\week 5\.venv\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (8.28.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.6.4)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.14.3)
# Requirement already satisfied: sktime==0.26.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\user\downloads\week 5\.venv\lib\site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.20.2)
# Requirement already satisfied: decorator in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (4.12.2)
# Requirement already satisfied: colorama in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: urllib3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (65.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (2024.8.30)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.4)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\user\downloads\week 5\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: six in c:\users\user\downloads\week 5\.venv\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\user\downloads\week 5\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\user\downloads\week 5\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\downloads\week 5\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.2)

# %%
# from pycaret.regression import setup

# automl = setup(df, target='MonthlyCharges')
# Out:
# <style type="text/css">
# #T_813ca_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_813ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_813ca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_813ca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_813ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_813ca_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_813ca_row0_col1" class="data row0 col1" >8369</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_813ca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_813ca_row1_col1" class="data row1 col1" >MonthlyCharges</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_813ca_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_813ca_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_813ca_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_813ca_row3_col1" class="data row3 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_813ca_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_813ca_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_813ca_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_813ca_row5_col1" class="data row5 col1" >(4930, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_813ca_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_813ca_row6_col1" class="data row6 col1" >(2113, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_813ca_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_813ca_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_813ca_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_813ca_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_813ca_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_813ca_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_813ca_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_813ca_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_813ca_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_813ca_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_813ca_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_813ca_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_813ca_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_813ca_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_813ca_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_813ca_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_813ca_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_813ca_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_813ca_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_813ca_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_813ca_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_813ca_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_813ca_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_813ca_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_813ca_row18_col1" class="data row18 col1" >f48a</td>
#     </tr>
#   </tbody>
# </table>

# %%
# # Checking for class imbalance in the target column
# df['MonthlyCharges'].value_counts()

# # If you find any classes with only one or very few samples, consider merging them or removing them
# # For example, if you want to remove rows with that class:
# df = df[df['MonthlyCharges'] != 'rare_class_value']  # Replace 'rare_class_value' with the actual class

# # Now try setting up pycaret again
# automl = setup(df, target='MonthlyCharges')
# Out:
# <style type="text/css">
# #T_5a67d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5a67d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a67d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5a67d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a67d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a67d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5a67d_row0_col1" class="data row0 col1" >4769</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a67d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5a67d_row1_col1" class="data row1 col1" >MonthlyCharges</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a67d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5a67d_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a67d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5a67d_row3_col1" class="data row3 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a67d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5a67d_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a67d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5a67d_row5_col1" class="data row5 col1" >(4930, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5a67d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5a67d_row6_col1" class="data row6 col1" >(2113, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5a67d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5a67d_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5a67d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5a67d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5a67d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5a67d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5a67d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5a67d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5a67d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5a67d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5a67d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5a67d_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5a67d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5a67d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5a67d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5a67d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5a67d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5a67d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5a67d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5a67d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5a67d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5a67d_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5a67d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5a67d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5a67d_row18_col1" class="data row18 col1" >f696</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import setup, compare_models

# Set up for regression
automl = setup(df, target='Churn',session_id=5906)

# Compare regression models
best_model = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_cdabd_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cdabd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdabd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cdabd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdabd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdabd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cdabd_row0_col1" class="data row0 col1" >5906</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdabd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cdabd_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdabd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cdabd_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cdabd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cdabd_row3_col1" class="data row3 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cdabd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cdabd_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cdabd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cdabd_row5_col1" class="data row5 col1" >(4930, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cdabd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cdabd_row6_col1" class="data row6 col1" >(2113, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cdabd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cdabd_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cdabd_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_cdabd_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cdabd_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_cdabd_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cdabd_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_cdabd_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cdabd_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_cdabd_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cdabd_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_cdabd_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cdabd_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_cdabd_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cdabd_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_cdabd_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cdabd_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_cdabd_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cdabd_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_cdabd_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cdabd_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_cdabd_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cdabd_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cdabd_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_cdabd_row18_col1" class="data row18 col1" >86ed</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_45ac2 th {
#   text-align: left;
# }
# #T_45ac2_row0_col0, #T_45ac2_row0_col3, #T_45ac2_row0_col4, #T_45ac2_row0_col5, #T_45ac2_row0_col7, #T_45ac2_row1_col0, #T_45ac2_row1_col1, #T_45ac2_row1_col2, #T_45ac2_row1_col3, #T_45ac2_row1_col4, #T_45ac2_row1_col5, #T_45ac2_row1_col6, #T_45ac2_row1_col7, #T_45ac2_row2_col0, #T_45ac2_row2_col1, #T_45ac2_row2_col2, #T_45ac2_row2_col3, #T_45ac2_row2_col4, #T_45ac2_row2_col5, #T_45ac2_row2_col6, #T_45ac2_row2_col7, #T_45ac2_row3_col0, #T_45ac2_row3_col1, #T_45ac2_row3_col2, #T_45ac2_row3_col3, #T_45ac2_row3_col5, #T_45ac2_row3_col6, #T_45ac2_row3_col7, #T_45ac2_row4_col0, #T_45ac2_row4_col1, #T_45ac2_row4_col2, #T_45ac2_row4_col3, #T_45ac2_row4_col4, #T_45ac2_row4_col5, #T_45ac2_row4_col6, #T_45ac2_row4_col7, #T_45ac2_row5_col0, #T_45ac2_row5_col1, #T_45ac2_row5_col2, #T_45ac2_row5_col3, #T_45ac2_row5_col4, #T_45ac2_row5_col5, #T_45ac2_row5_col6, #T_45ac2_row5_col7, #T_45ac2_row6_col0, #T_45ac2_row6_col1, #T_45ac2_row6_col2, #T_45ac2_row6_col3, #T_45ac2_row6_col4, #T_45ac2_row6_col5, #T_45ac2_row6_col6, #T_45ac2_row6_col7, #T_45ac2_row7_col0, #T_45ac2_row7_col1, #T_45ac2_row7_col2, #T_45ac2_row7_col3, #T_45ac2_row7_col4, #T_45ac2_row7_col5, #T_45ac2_row7_col6, #T_45ac2_row7_col7, #T_45ac2_row8_col0, #T_45ac2_row8_col1, #T_45ac2_row8_col2, #T_45ac2_row8_col3, #T_45ac2_row8_col4, #T_45ac2_row8_col5, #T_45ac2_row8_col6, #T_45ac2_row8_col7, #T_45ac2_row9_col0, #T_45ac2_row9_col1, #T_45ac2_row9_col2, #T_45ac2_row9_col3, #T_45ac2_row9_col4, #T_45ac2_row9_col6, #T_45ac2_row10_col0, #T_45ac2_row10_col1, #T_45ac2_row10_col2, #T_45ac2_row10_col3, #T_45ac2_row10_col4, #T_45ac2_row10_col5, #T_45ac2_row10_col6, #T_45ac2_row10_col7, #T_45ac2_row11_col0, #T_45ac2_row11_col1, #T_45ac2_row11_col2, #T_45ac2_row11_col3, #T_45ac2_row11_col4, #T_45ac2_row11_col5, #T_45ac2_row11_col6, #T_45ac2_row11_col7, #T_45ac2_row12_col0, #T_45ac2_row12_col1, #T_45ac2_row12_col2, #T_45ac2_row12_col4, #T_45ac2_row12_col5, #T_45ac2_row12_col6, #T_45ac2_row12_col7, #T_45ac2_row13_col0, #T_45ac2_row13_col1, #T_45ac2_row13_col2, #T_45ac2_row13_col3, #T_45ac2_row13_col4, #T_45ac2_row13_col5, #T_45ac2_row13_col6, #T_45ac2_row13_col7 {
#   text-align: left;
# }
# #T_45ac2_row0_col1, #T_45ac2_row0_col2, #T_45ac2_row0_col6, #T_45ac2_row3_col4, #T_45ac2_row9_col5, #T_45ac2_row9_col7, #T_45ac2_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_45ac2_row0_col8, #T_45ac2_row1_col8, #T_45ac2_row2_col8, #T_45ac2_row3_col8, #T_45ac2_row4_col8, #T_45ac2_row5_col8, #T_45ac2_row6_col8, #T_45ac2_row7_col8, #T_45ac2_row8_col8, #T_45ac2_row10_col8, #T_45ac2_row11_col8, #T_45ac2_row12_col8, #T_45ac2_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_45ac2_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_45ac2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45ac2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45ac2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_45ac2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_45ac2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_45ac2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_45ac2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_45ac2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_45ac2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_45ac2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45ac2_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_45ac2_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_45ac2_row0_col1" class="data row0 col1" >0.7961</td>
#       <td id="T_45ac2_row0_col2" class="data row0 col2" >0.8391</td>
#       <td id="T_45ac2_row0_col3" class="data row0 col3" >0.5107</td>
#       <td id="T_45ac2_row0_col4" class="data row0 col4" >0.6465</td>
#       <td id="T_45ac2_row0_col5" class="data row0 col5" >0.5696</td>
#       <td id="T_45ac2_row0_col6" class="data row0 col6" >0.4388</td>
#       <td id="T_45ac2_row0_col7" class="data row0 col7" >0.4445</td>
#       <td id="T_45ac2_row0_col8" class="data row0 col8" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_45ac2_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_45ac2_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_45ac2_row1_col1" class="data row1 col1" >0.7947</td>
#       <td id="T_45ac2_row1_col2" class="data row1 col2" >0.8373</td>
#       <td id="T_45ac2_row1_col3" class="data row1 col3" >0.5100</td>
#       <td id="T_45ac2_row1_col4" class="data row1 col4" >0.6441</td>
#       <td id="T_45ac2_row1_col5" class="data row1 col5" >0.5681</td>
#       <td id="T_45ac2_row1_col6" class="data row1 col6" >0.4361</td>
#       <td id="T_45ac2_row1_col7" class="data row1 col7" >0.4419</td>
#       <td id="T_45ac2_row1_col8" class="data row1 col8" >0.1330</td>
#     </tr>
#     <tr>
#       <th id="T_45ac2_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_45ac2_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_45ac2_row2_col1" class="data row2 col1" >0.7933</td>
#       <td id="T_45ac2_row2_col2" class="data row2 col2" >0.8344</td>
#       <td id="T_45ac2_row2_col3" class="data row2 col3" >0.5138</td>
#       <td id="T_45ac2_row2_col4" class="data row2 col4" >0.6383</td>
#       <td id="T_45ac2_row2_col5" class="data row2 col5" >0.5677</td>
#       <td id="T_45ac2_row2_col6" class="data row2 col6" >0.4343</td>
#       <td id="T_45ac2_row2_col7" class="data row2 col7" >0.4397</td>
#       <td id="T_45ac2_row2_col8" class="data row2 col8" >0.1160</td>
#     </tr>
#     <tr>
#       <th id="T_45ac2_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_45ac2_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_45ac2_row3_col1" class="data row3 col1" >0.7927</td>
#       <td id="T_45ac2_row3_col2" class="data row3 col2" >0.8205</td>
#       <td id="T_45ac2_row3_col3" class="data row3 col3" >0.4618</td>
#       <td id="T_45ac2_row3_col4" class="data row3 col4" >0.6569</td>
#       <td id="T_45ac2_row3_col5" class="data row3 col5" >0.5411</td>
#       <td id="T_45ac2_row3_col6" class="data row3 col6" >0.4127</td>
#       <td id="T_45ac2_row3_col7" class="data row3 col7" >0.4240</td>
#       <td id="T_45ac2_row3_col8" class="data row3 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_45ac2_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_45ac2_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_45ac2_row4_col1" class="data row4 col1" >0.7895</td>
#       <td id="T_45ac2_row4_col2" class="data row4 col2" >0.8238</td>
#       <td id="T_45ac2_row4_col3" class="data row4 col3" >0.5298</td>
#       <td id="T_45ac2_row4_col4" class="data row4 col4" >0.6225</td>
#       <td id="T_45ac2_row4_col5" class="data row4 col5" >0.5713</td>
#       <td id="T_45ac2_row4_col6" class="data row4 col6" >0.4332</td>
#       <td id="T_45ac2_row4_col7" class="data row4 col7" >0.4363</td>
#       <td id="T_45ac2_row4_col8" class="data row4 col8" >0.1840</td>
#     </tr>
#     <tr>
#       <th id="T_45ac2_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_45ac2_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_45ac2_row5_col1" class="data row5 col1" >0.7866</td>
#       <td id="T_45ac2_row5_col2" class="data row5 col2" >0.8205</td>
#       <td id="T_45ac2_row5_col3" class="data row5 col3" >0.4977</td>
#       <td id="T_45ac2_row5_col4" class="data row5 col4" >0.6234</td>
#       <td id="T_45ac2_row5_col5" class="data row5 col5" >0.5525</td>
#       <td id="T_45ac2_row5_col6" class="data row5 col6" >0.4149</td>
#       <td id="T_45ac2_row5_col7" class="data row5 col7" >0.4200</td>

# %%
best_model
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=5906, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
df.iloc[-2:-1]
# Out:
#       tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 7041       4             1         0              3            74.4
#
#       TotalCharges  Churn
# 7041         297.6      1

# %%
save_model(best_model, 'XGBoost2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'PhoneService',
#                                               'Contract', 'PaymentMethod',
#                                               'MonthlyCharges', 'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',...
#                                              criterion='friedman_mse', init=None,
#                                              learning_rate=0.1, loss='log_loss',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              random_state=5906, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False))],
#           verbose=False),
#  'XGBoost2.pkl')

# %%
import pickle
with open('XGBoost2.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('XGBoost2.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
loaded_lda = load_model('XGBoost2')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# new_data=df.iloc[-2:-1]

# %%
new_data=df.copy()

# %%
# from pycaret.regression import setup, save_model, load_model, predict_model

# # Re-run setup for regression instead of classification
# automl = setup(df, target='MonthlyCharges')

# # # Train a model (e.g., best_model)
# # best_model = compare_models()

# # # Save the trained model
# # save_model(best_model, 'saved_lda_model')

# # # Load the previously saved model
# # loaded_lda = load_model('saved_lda_model')

# # # Make predictions using the loaded model
# # predictions = predict_model(loaded_lda, data=new_data)

# # # Display the predictions
# # print(predictions)

# %%
# # Train a model (e.g., best_model)
# best_model = compare_models(sort='AUC')
# # final
# # Save the trained model
# save_model(best_model, 'saved_lda_model')

# # Load the previously saved model
# loaded_lda = load_model('saved_lda_model')

# Make predictions using the loaded model
predictions = predict_model(loaded_lda, data=new_data)

# Display the predictions
print(predictions)
# Out:
# <style type="text/css">
# </style>
# <table id="T_91bbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91bbf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_91bbf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_91bbf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_91bbf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_91bbf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_91bbf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_91bbf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_91bbf_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91bbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91bbf_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_91bbf_row0_col1" class="data row0 col1" >0.8143</td>
#       <td id="T_91bbf_row0_col2" class="data row0 col2" >0.8625</td>
#       <td id="T_91bbf_row0_col3" class="data row0 col3" >0.5388</td>
#       <td id="T_91bbf_row0_col4" class="data row0 col4" >0.6930</td>
#       <td id="T_91bbf_row0_col5" class="data row0 col5" >0.6063</td>
#       <td id="T_91bbf_row0_col6" class="data row0 col6" >0.4872</td>
#       <td id="T_91bbf_row0_col7" class="data row0 col7" >0.4938</td>
#     </tr>
#   </tbody>
# </table>
#       tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0          1             0         0              2       29.850000
# 1         34             1         1              3       56.950001
# 2          2             1         0              3       53.849998
# 3         45             0         1              0       42.299999
# 4          2             1         0              2       70.699997
# ...      ...           ...       ...            ...             ...
# 7038      24             1         1              3       84.800003
# 7039      72             1         1              1      103.199997
# 7040      11             0         0              2       29.600000
# 7041       4             1         0              3       74.400002
# 7042      66             1         2              0      105.650002
#
#       TotalCharges  Churn  prediction_label  prediction_score
# 0        29.850000      0                 0            0.5026
# 1      1936.300049      0                 0            0.9530
# 2       107.699997      1                 0            0.6286
# 3      1903.500000      0                 0            0.9157
# 4       141.399994      1                 1            0.6685
# ...            ...    ...               ...               ...
# 7038   2035.199951      0                 0            0.9193
# 7039   7430.399902      0                 0            0.9195
# 7040    325.600006      0                 0            0.7479
# 7041    297.600006      1                 1            0.5592
# 7042   6972.899902      0                 0            0.9351
#
# [7043 rows x 9 columns]

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# model = load_model('XGBoost2')
#
# def load_data(filepath):
#     """
#     Loads churn data into a DataFrame from a string filepath.
#     """
#     df = pd.read_csv('new_churn_data.csv', index_col='customerID')
#     return df
#
#
# def make_predictions(df, threshold=0.65):
#     """
#     Uses the pycaret best model to make predictions on data in the df dataframe.
#     Rounds up to 1 if greater than or equal to the threshold.
#     """
#     predictions = predict_model(model, data=df)
#     predictions['Churn_prediction'] = (predictions['prediction_Score'] >= threshold)
#     predictions['Churn_prediction'].replace({True: 0, False: 1}, inplace=True)
#     drop_cols = predictions.columns.tolist()
#     drop_cols.remove('Churn_prediction')
#     return predictions.drop(drop_cols, axis=1)
#     # return predictions['prediction_label']
#
#
# if __name__ == "__main__":
#     df = load_data('new_churn_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %%
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
# predictions:
#             Churn_prediction
# customerID
# 9305-CKSKC                 1
# 1452-KNGVK                 0
# 6723-OKKJM                 0
# 7832-POPKP                 1
# 6348-TACGU                 0

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.

# %% [markdown]
# Using PyCaret, we:
#
#
# 1. Loaded and prepared the churn data.
# 2. Compared ML algorithms and selected the best performer based on AUC.
# 3. Saved the tuned model to disk.
# 4. Created a Python function to predict churn probability.
# 5. Tested the function with new data.
#
#
# **Results:**
#
#
# The best-performing model achieved an AUC of 0.86.
#
# True values: [1, 0, 0, 1, 0]
#
#
# The model demonstrated excellent performance on both training and testing data.
#
# **Recommendations:**
# 1. Monitor model performance on new data.
# 2. Continuously collect and incorporate new data to improve model accuracy.
# 3. Explore feature engineering and hyperparameter tuning for further improvements.

# %%
![image.png](attachment:image.png)
# Out:
# '[image.png]' is not recognized as an internal or external command,
# operable program or batch file.
